# %% [markdown]
# ## 総合演習（その２）
# ## 手書き数字の認識（その２）

# %% [markdown]
# ### （１）手書き数字の認識のニューラルネットワークを使用して、数字の１のいくつかのパターンを学習させます。
# ### （２）学習させたそのニューラルネットワークに新しいパターンの数字の１を与えて正しく予測できるかを実現するネットワークを実装します

# %% [markdown]
# ### 👇下記の指示に従って実装してください
# ### ➀ 下記の関数を本JupyterNotebook テキストがある場所と同じ場所に my_ml.py という名前で作成してください
# ### ◆重みを生成する関数 create_weights の定義
# ### ◆加重和（内積）を求める関数 w_sum の定義
# ### ◆ベクトルと行列のかけ算を求める関数 vect_mat_mul の定義
# ### ◆２つのリストの要素間を総なめして要素ごとのかけ算をしてその結果を行列に格納する関数 outer_prod の定義
# ### ◆予測値を求める関数 nuural_network の定義
# ### ◆学習関数 grad_descent_learn(input, truth, pred, weights, alpha) の定義

# %% [markdown]
# ### ② 下記の未完成リストのコメント部分に従ってプログラムを実装してください。実行結果も参照してください。

# %%
import my_ml as ml

# 手書き文字データの初期化
# 数字１ パターン１
number_1_str = [
  "    11    ",
  "    11    ",
  "   111    ",
  "   111    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "    11    "
]
# 数字１ パターン２
number_1_str_2 = [
  "    11    ",
  "    11    ",
  "   111    ",
  "   111    ",
  "    11    ",
  "   11     ",
  "  11      ",
  "  11      ",
  "  11      ",
  "  11      "
]
# 数字１ パターン３
number_1_str_3 = [
  "    11    ",
  "    11    ",
  "   111    ",
  "   111    ",
  "    11    ",
  "          ",
  "    11    ",
  "    11    ",
  "    11    ",
  "    11    "
]
# 数字１ 認識できるか？
number_1_str_4 = [
  "    11    ",
  "   111    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "   11     ",
  "  11      ",
  "  11      ",
  "  11      ",
  "  11      "
]

new_number_str = [
  "    11    ",
  "   111    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "    11    ",
  "   11     ",
  "   11     "
]

# 文字列配列を数値配列に変換する関数 str_to_number_list の定義
'''
関数名：str_to_number_list
引数：str = 手書き文字列（文字列のリスト）
処理：手書き文字列（文字列リスト）を数値リストに変換
戻り値：数値２次元配列
'''


# 認識した数値を返す関数 number_recognition 関数の定義
'''
関数名：number_recognition
引数：pred = 予測値リスト
処理：
  予測値リストの最大値が存在する要素番号を返す
戻り値：最大値の要素番号＝認識した数字
'''



# 数字１ パターン１の設定
input_1 = 
# 数字１ パターン２の設定
input_2 = 
# 数字１ パターン３の設定
input_3 = 
# 数字１ パターン４の設定
input_4 = 

# 学習用入力データの設定
input = 

# 目的値（正解）の設定（数字の１を学習させる）
truth = 

# 重みを生成


# アルファの初期化
alpha = 0.001

# １数字１のパターン１からパターン４までをそれぞれ３００回学習


# 数字１　新たなパターンの予測
print('新たなパターンの数字１の認識')

# 認識した数字を求める

# 認識結果を表示する
# Out:
# 数字１の学習：パターン 1
# 数字１：パターン 1 の学習終了
# 数字１の学習：パターン 2
# 数字１：パターン 2 の学習終了
# 数字１の学習：パターン 3
# 数字１：パターン 3 の学習終了
# 数字１の学習：パターン 4
# 数字１：パターン 4 の学習終了
# 新たなパターンの数字１の認識
# 認識 =  1
