# %% [markdown]
# ## 総合問題（図形の認識）
# ### ▶ 下図の図形を認識するニューラルネットワークにおいて学習して新しい図形を認識するプログラムを未完成リストのコメントに従って実装してください。
# ![](chap5_ex_5.png)

# %% [markdown]
# ### 👇未完成リスト

# %%
import my_ml as ml

# 図形文字データの初期化
# ３角形　タイプ１
fig_triangle_1_str = [
  "          ",
  "    11    ",
  "   1111   ",
  "  111111  ",
  " 11111111 ",
  "1111111111",
  "          ",
  "          ",
  "          ",
  "          "
]

# ３角形　タイプ２
fig_triangle_2_str = [
  "          ",
  "   11     ",
  "  1111    ",
  " 111111   ",
  " 11111111 ",
  "1111111111",
  "          ",
  "          ",
  "          ",
  "          "
]

# ３角形　タイプ３
fig_triangle_3_str = [
  "          ",
  " 11       ",
  " 1111     ",
  " 111111   ",
  "11111111  ",
  "1111111111",
  "          ",
  "          ",
  "          ",
  "          "
]

# ３角形　タイプ４
fig_triangle_4_str = [
  "          ",
  "11        ",
  "1111      ",
  "111111    ",
  "11111111  ",
  "1111111111",
  "          ",
  "          ",
  "          ",
  "          "
]

# 予測させる３角形
fig_new_triangle_str = [
  "          ",
  "  11      ",
  " 1111     ",
  " 111111   ",
  " 11111111 ",
  "1111111111",
  "          ",
  "          ",
  "          ",
  "          "
]


# 文字列配列を数値配列に変換する関数 str_to_number_list の定義
'''
関数名：str_to_number_list
引数：str = 手書き文字列（文字列のリスト）
処理：手書き文字列（文字列リスト）を数値リストに変換
戻り値：数値２次元配列
'''

  # 数値リストの初期化
  
  # 文字列リストを数値リストに変換（２重ループ）
  # 文字 '1' なら数値の 1 に、空白文字 ' ' なら数値の 0 に変換
  # 行数分繰り返す
  
    # 列数分（文字数分）繰り返す
    
      # 文字が '1' なら
      
        # 数値リストに 1 を追加する
        
      # そうでなければ
      else:
        # 数値リストに 0 を追加する
        
  # 数値リストを返す
  

# 図形を予測する関数 figure_recognition の定義
'''
関数名：figure_recognition
引数：pred = 予測値リスト
処理：
  予測値リストの最大値のインデックス番号（リストの要素番号を求めて）
  '３角形'、'長方形'、'その他' を返す
戻り値：'３角形' または '長方形' または 'その他'
'''

  # max メソッド, index メソッドを使用して、予測値リスト pred の最大値のインデックス番号を求める
  max_index = 
  # 図形を判断する
  # ３角形かどうかの判断
  
    # '３角形' を返す
    
  # その他のとき
  else:
    # 'その他' を返す
    return 'その他'

# 入力データの設定
# ３角形　タイプ１

# ３角形　タイプ２

# ３角形　タイプ３

# ３角形　タイプ４


# ３角形入力データの設定


# 目的値（正解）の設定
truth = [
  # ３角形
  [1, 0],
  # その他
  [0, 1]
]

# 重みを生成

# アルファの初期化
alpha = 0.001

# ３角形を３００回学習する
print('学習開始')

  # タイプ１からタイプ４の３角形の学習
  
    # 予測値リストを求める
    
    # 学習する（重みを調整して更新する）
    
print('学習終了')

# 予測させる３角形の入力データを設定


# 新しいタイプの３角形を予測

# 予測した図形を表示
# Out:
# 学習開始
# 学習終了
# 予測した図形 = ３角形
